# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("churn.csv")

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# ##### CustomerId : Müşteriye atanan ID numarası Sürekli Bir değişkendir
# ##### Surname : Müşterinin Soyadı
# ##### CreditScore : Müşterinin Kredi Skoru Sürekli bir değişkendir
# ##### Geopraphy : Müşterinin Kökeni kategorik bir değişkendir
# ##### Gender : Müşterinin Cinsiyeti kategorik değişkendir
# ##### Age : Müşterinin Yaşı Kesikli bir değişkendir
# ##### Tenure : Müşterinin Kaç yıldır müşteri olduğu kesikli bir değişkendir
# ##### Balance : Anlık Para sürekli bir değişkendir
# ##### NumOfProducts : Müşterinin Banka aracalığıyla aldığı ürün kesikli bir değişkendir
# ##### HasCrCard : Müşterinin bankaya ait olduğu kredi kartı sayısı kesikli bir değişkendir
# ##### İsActiveMember : Müşterinin Aktif hesabı olup olmadığı sayısal kategorik değişken
# ##### EstimatedSalary : Tahmini Maaş sürekli değişken
# ##### Exited : Müşterinin Bankadan ayrılıp ayrılmadığını sayısal kategorik değişken

# %%
# Burada RowNumber kolonu bize her hangi bir bilgi ifade etmeyeceği için siliyoruz.
data.drop(["RowNumber"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
data.dtypes
# Out:
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
# burada kategorik olarak belirlediğimiz kolonları object'ten kategoriye çevirioyruz
category = ["Geography","Gender","Tenure","NumOfProducts","HasCrCard","IsActiveMember","Exited"]
for i in category:
    data[i] = data[i].astype("category")

# %%
data.dtypes
# Out:
# CustomerId            int64
# Surname              object
# CreditScore           int64
# Geography          category
# Gender             category
# Age                   int64
# Tenure             category
# Balance             float64
# NumOfProducts      category
# HasCrCard          category
# IsActiveMember     category
# EstimatedSalary     float64
# Exited             category
# dtype: object

# %%
data.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age Tenure    Balance  \
# 0    15634602  Hargrave          619    France  Female   42      2       0.00
# 1    15647311      Hill          608     Spain  Female   41      1   83807.86
# 2    15619304      Onio          502    France  Female   42      8  159660.80
# 3    15701354      Boni          699    France  Female   39      1       0.00
# 4    15737888  Mitchell          850     Spain  Female   43      2  125510.82
#
#   NumOfProducts HasCrCard IsActiveMember  EstimatedSalary Exited
# 0             1         1              1        101348.88      1
# 1             1         0              1        112542.58      0
# 2             3         1              0        113931.57      1
# 3             2         0              0         93826.63      0
# 4             1         1              1         79084.10      0

# %%
# Burada Kredi skor ortalamasını hesaplıyoruz
krediSkorOrtalama = data["CreditScore"].mean()
varlıkDurumu = data["EstimatedSalary"].mean()
print("Kredi Skor Ortalama: ",krediSkorOrtalama)
print("Varlık Durumu Ortalama: ",varlıkDurumu)
# Out:
# Kredi Skor Ortalama:  650.5288
# Varlık Durumu Ortalama:  100090.239881

# %%
# İlk olarak kredi skor durumunu belli edicek bir değişken oluşturalım
data["KrediSkorDurumu"] = ["Düşük" if i < krediSkorOrtalama else "Yüksek" for i in data["CreditScore"]]

# %%
data
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age Tenure  \
# 0       15634602   Hargrave          619    France  Female   42      2
# 1       15647311       Hill          608     Spain  Female   41      1
# 2       15619304       Onio          502    France  Female   42      8
# 3       15701354       Boni          699    France  Female   39      1
# 4       15737888   Mitchell          850     Spain  Female   43      2
# ...          ...        ...          ...       ...     ...  ...    ...
# 9995    15606229   Obijiaku          771    France    Male   39      5
# 9996    15569892  Johnstone          516    France    Male   35     10
# 9997    15584532        Liu          709    France  Female   36      7
# 9998    15682355  Sabbatini          772   Germany    Male   42      3
# 9999    15628319     Walker          792    France  Female   28      4
#
#         Balance NumOfProducts HasCrCard IsActiveMember  EstimatedSalary  \
# 0          0.00             1         1              1        101348.88
# 1      83807.86             1         0              1        112542.58
# 2     159660.80             3         1              0        113931.57
# 3          0.00             2         0              0         93826.63
# 4     125510.82             1         1              1         79084.10
# ...         ...           ...       ...            ...              ...
# 9995       0.00             2         1              0         96270.64
# 9996   57369.61             1         1              1        101699.77
# 9997       0.00             1         0              1         42085.58
# 9998   75075.31             2         1              0         92888.52
# 9999  130142.79             1         1              0         38190.78
#
#      Exited KrediSkorDurumu
# 0         1           Düşük
# 1         0           Düşük
# 2         1           Düşük
# 3         0          Yüksek
# 4         0          Yüksek
# ...     ...             ...
# 9995      0          Yüksek
# 9996      0           Düşük
# 9997      1          Yüksek
# 9998      1          Yüksek
# 9999      0          Yüksek
#
# [10000 rows x 14 columns]

# %%
# sonrasında bankaya sağdık ve sağdık değil diye bir değişken oluşturalım
data["SadıklıkDurumu"] = ["Sadık" if i >=5 else "Sadık Değil" for i in data["Tenure"]]

# %%
data.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age Tenure    Balance  \
# 0    15634602  Hargrave          619    France  Female   42      2       0.00
# 1    15647311      Hill          608     Spain  Female   41      1   83807.86
# 2    15619304      Onio          502    France  Female   42      8  159660.80
# 3    15701354      Boni          699    France  Female   39      1       0.00
# 4    15737888  Mitchell          850     Spain  Female   43      2  125510.82
#
#   NumOfProducts HasCrCard IsActiveMember  EstimatedSalary Exited  \
# 0             1         1              1        101348.88      1
# 1             1         0              1        112542.58      0
# 2             3         1              0        113931.57      1
# 3             2         0              0         93826.63      0
# 4             1         1              1         79084.10      0
#
#   KrediSkorDurumu SadıklıkDurumu
# 0           Düşük    Sadık Değil
# 1           Düşük    Sadık Değil
# 2           Düşük          Sadık
# 3          Yüksek    Sadık Değil
# 4          Yüksek    Sadık Değil

# %%
# daha sonra ise bu elimizdeki veriye göre zengin olup olmadığını belirleyelim (bunu yaparken de varlık durumunu baz alıcaz)
data["ZenginlikDurumu"] = ["Varlıklı" if i >= varlıkDurumu else "Varlıksız" for i in data["EstimatedSalary"]]

# %%
data.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age Tenure    Balance  \
# 0    15634602  Hargrave          619    France  Female   42      2       0.00
# 1    15647311      Hill          608     Spain  Female   41      1   83807.86
# 2    15619304      Onio          502    France  Female   42      8  159660.80
# 3    15701354      Boni          699    France  Female   39      1       0.00
# 4    15737888  Mitchell          850     Spain  Female   43      2  125510.82
#
#   NumOfProducts HasCrCard IsActiveMember  EstimatedSalary Exited  \
# 0             1         1              1        101348.88      1
# 1             1         0              1        112542.58      0
# 2             3         1              0        113931.57      1
# 3             2         0              0         93826.63      0
# 4             1         1              1         79084.10      0
#
#   KrediSkorDurumu SadıklıkDurumu ZenginlikDurumu
# 0           Düşük    Sadık Değil        Varlıklı
# 1           Düşük    Sadık Değil        Varlıklı
# 2           Düşük          Sadık        Varlıklı
# 3          Yüksek    Sadık Değil       Varlıksız
# 4          Yüksek    Sadık Değil       Varlıksız

# %%
# Şu anki varlığı ortalama maaşından düşük mü ?
data["VarlığıOrtalamaMaaştanDüşük"] = ["Düşük" if i < varlıkDurumu else "Yüksek" for i in data["EstimatedSalary"]]

# %%
data.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age Tenure    Balance  \
# 0    15634602  Hargrave          619    France  Female   42      2       0.00
# 1    15647311      Hill          608     Spain  Female   41      1   83807.86
# 2    15619304      Onio          502    France  Female   42      8  159660.80
# 3    15701354      Boni          699    France  Female   39      1       0.00
# 4    15737888  Mitchell          850     Spain  Female   43      2  125510.82
#
#   NumOfProducts HasCrCard IsActiveMember  EstimatedSalary Exited  \
# 0             1         1              1        101348.88      1
# 1             1         0              1        112542.58      0
# 2             3         1              0        113931.57      1
# 3             2         0              0         93826.63      0
# 4             1         1              1         79084.10      0
#
#   KrediSkorDurumu SadıklıkDurumu ZenginlikDurumu VarlığıOrtalamaMaaştanDüşük
# 0           Düşük    Sadık Değil        Varlıklı                      Yüksek
# 1           Düşük    Sadık Değil        Varlıklı                      Yüksek
# 2           Düşük          Sadık        Varlıklı                      Yüksek
# 3          Yüksek    Sadık Değil       Varlıksız                       Düşük
# 4          Yüksek    Sadık Değil       Varlıksız                       Düşük

# %%
# Burada Sadıklık durumunun kredi ürünleri ile alaksı var mı diye bakıyoruz
# Frekans dağılımını kullanalım
plt.figure(figsize=(10,10))
plt.title("Sadıklık Durumuna Göre Kredi Ürünleri")
plt.xlabel("Sadıklık Durumu")
plt.ylabel("kredi kullanma oranı")
sns.countplot(x="SadıklıkDurumu",hue="HasCrCard",data=data)
plt.show()

# %%
# bunu istatistiksel testler ile de doğrulayalım
from scipy.stats import chi2_contingency
soru1 = chi2_contingency(pd.crosstab(data["HasCrCard"],data["SadıklıkDurumu"]))
#H0: İlişki Yoktur
#H1: İlişki Vardır
# beklenene değer frekansı oluştur ve %5'in altında beklenen değer varsa Fishcer excat ki kare testi uygula

# %%
soru1
# burada p değerimiz "0.289" çıktı yani 0.05'ten büyük olduğu için H0 hipotezini reddedemiyoruz.
# Out:
# Chi2ContingencyResult(statistic=1.1219820883900833, pvalue=0.2894920590523776, dof=1, expected_freq=array([[1621.517, 1323.483],
#        [3884.483, 3170.517]]))

# %%
# şimdi de sadıklık durumunun ırkla alakası var mı gözlemleyelim
plt.figure(figsize=(10,10))
plt.title("Sadıklık Durumuna Göre Irk")
plt.xlabel("Sadıklık Durumu")
plt.ylabel("Irk")
sns.countplot(x="SadıklıkDurumu",hue="Geography",data=data)
plt.show()

# %%
# buna bir de istatistiksel test uygulayalım
soru2 = chi2_contingency(pd.crosstab(data["Geography"],data["SadıklıkDurumu"]))
# H0: İlişki Yoktur
# H1: İlişki Vardır

# %%
soru2.pvalue
# burada p değerimiz "0.689" çıktı yani 0.05'ten büyük olduğu için H0 hipotezini reddedemiyoruz.
# Out:
# 0.689551789243679

# %%
# Sadıklık durumu Cinsiyetle alakalı mı ?
plt.figure(figsize=(10,10))
plt.title("Sadıklık Durumuna Göre Cinsiyet")
plt.xlabel("Sadıklık Durumu")
plt.ylabel("Cinsiyet")
sns.countplot(x="SadıklıkDurumu",hue="Gender",data=data)
plt.show()

# %%
# buna da istatistiksel test uygulayalım
soru3 = chi2_contingency(pd.crosstab(data["Gender"],data["SadıklıkDurumu"]))
# H0: İlişki Yoktur
# H1: İlişki Vardır

# %%
soru3.pvalue
# burada p değerimiz "0.21" çıktı yani 0.05'ten büyük olduğu için H0 hipotezini reddedemiyoruz.
# Out:
# 0.2125356579824753

# %%
# Varlık durumunun kredi kullanımına etkisi var mı ?
plt.figure(figsize=(10,10))
plt.title("Varlık Durumuna Göre Kredi Kullanımı")
plt.xlabel("Varlık Durumu")
plt.ylabel("Kredi Kullanımı")
sns.countplot(x="ZenginlikDurumu",hue="HasCrCard",data=data)
plt.show()

# %%
# buna da istatistiksel test uygulayalım
soru4 = chi2_contingency(pd.crosstab(data["HasCrCard"],data["ZenginlikDurumu"]))
# H0: İlişki Yoktur
# H1: İlişki Vardır

# %%
soru4.pvalue
# Burada 0.27 çıktı yani 0.05'ten büyük olduğu için H0 hipotezini reddedemiyoruz.
# Out:
# 0.2738530419733728

# %%
# peki kredi skorunun varlıkla alakası var mı ?
plt.figure(figsize=(10,10))
plt.title("Kredi Skoruna Göre Varlık Durumu")
plt.xlabel("Kredi Skoru")
plt.ylabel("Varlık Durumu")
sns.countplot(x="KrediSkorDurumu",hue="ZenginlikDurumu",data=data)
plt.show()

# %%
# buna da istatistiksel test uygulayalım
soru5 = chi2_contingency(pd.crosstab(data["KrediSkorDurumu"],data["ZenginlikDurumu"]))
# H0: İlişki Yoktur
# H1: İlişki Vardır

# %%
soru5.pvalue
# Burada 0.91 çıktı yani 0.05'ten büyük olduğu için H0 hipotezini reddedemiyoruz.
# Out:
# 0.9189375091235191

# %%
#### ÇÖZÜMLER

# %%
data.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age Tenure    Balance  \
# 0    15634602  Hargrave          619    France  Female   42      2       0.00
# 1    15647311      Hill          608     Spain  Female   41      1   83807.86
# 2    15619304      Onio          502    France  Female   42      8  159660.80
# 3    15701354      Boni          699    France  Female   39      1       0.00
# 4    15737888  Mitchell          850     Spain  Female   43      2  125510.82
#
#   NumOfProducts HasCrCard IsActiveMember  EstimatedSalary Exited  \
# 0             1         1              1        101348.88      1
# 1             1         0              1        112542.58      0
# 2             3         1              0        113931.57      1
# 3             2         0              0         93826.63      0
# 4             1         1              1         79084.10      0
#
#   KrediSkorDurumu SadıklıkDurumu ZenginlikDurumu VarlığıOrtalamaMaaştanDüşük
# 0           Düşük    Sadık Değil        Varlıklı                      Yüksek
# 1           Düşük    Sadık Değil        Varlıklı                      Yüksek
# 2           Düşük          Sadık        Varlıklı                      Yüksek
# 3          Yüksek    Sadık Değil       Varlıksız                       Düşük
# 4          Yüksek    Sadık Değil       Varlıksız                       Düşük

# %%
# burada X yaşından küçük kadınlara "Moda kredisi " adı altında bir teklif sunmak isteyelim bize bu kriterlere uygun müşterileri getirecek bir fonksiyon yazalım 
def ModaKredisi(X,df):
    modaKredisi = data[(data["Age"] < X) & (data["Gender"]=="Female")]     
    return modaKredisi

# %%
krediTeklifiX1 = ModaKredisi(30,data)

# %%
krediTeklifiX1[
    (krediTeklifiX1["IsActiveMember"] == 1) & (krediTeklifiX1["Exited"] == 0) & (krediTeklifiX1["HasCrCard"] == 1) & (krediTeklifiX1["KrediSkorDurumu"] == "Yüksek") & (krediTeklifiX1["SadıklıkDurumu"] == "Sadık Değil") & (krediTeklifiX1["ZenginlikDurumu"] == "Varlıksız")
]
# Out:
#       CustomerId     Surname  CreditScore Geography  Gender  Age Tenure  \
# 998     15659557  Artamonova          811   Germany  Female   28      4
# 1134    15732660       Black          769    France  Female   27      2
# 1213    15624229       Noble          694    France  Female   22      4
# 1412    15588986       Grant          673   Germany  Female   29      4
# 1472    15729956    Akabueze          726     Spain  Female   26      1
# 2001    15734311    Hamilton          661    France  Female   27      3
# 2324    15748116    Zetticci          681    France  Female   29      2
# 2422    15607837      Muriel          746    France  Female   29      4
# 3031    15638963      Garran          678    France  Female   22      4
# 3800    15685314       Noble          850    France  Female   28      2
# 4003    15626141     Fedorov          750    France  Female   26      1
# 4120    15610105        Shen          666   Germany  Female   21      1
# 4146    15698246      Gordon          658    France  Female   24      2
# 4186    15702175      Herrin          755    France  Female   29      4
# 4253    15599869       Dyson          728     Spain  Female   29      1
# 4369    15781495       Munro          662    France  Female   22      2
# 4556    15796231     Nwankwo          681    France  Female   18      1
# 5586    15699446       Hobbs          816   Germany  Female   25      2
# 5675    15757897      Binder          766    France  Female   26      3
# 6885    15606849    Blackall          698    France  Female   27      1
# 7113    15783859        Boni          733    France  Female   24      3
# 7806    15750410      Jordan          680    France  Female   25      4
# 7859    15646374       Wynne          766   Germany  Female   28      3
# 7985    15678427    Genovese          696   Germany  Female   27      2
# 9379    15626042        Webb          690     Spain  Female   26      2
# 9469    15674573    Gearhart          713    France  Female   25      4
#
#         Balance NumOfProducts HasCrCard IsActiveMember  EstimatedSalary  \
# 998   167738.82             2         1              1          9903.42
# 1134       0.00             1         1              1         57876.05
# 1213       0.00             2         1              1         11525.72
# 1412   99097.36             1         1              1          9796.69
# 1472   80780.16             1         1              1         19225.85
# 2001       0.00             2         1              1         76889.79
# 2324  148143.84             1         1              1         52021.39
# 2422  105599.67             1         1              1         43106.17
# 3031  174852.89             1         1              1         28149.06
# 3800       0.00             2         1              1         38773.74
# 4003  151510.17             2         1              1         19921.72
# 4120  121827.43             2         1              1         99818.31
# 4146       0.00             2         1              1         84694.49
# 4186  148654.84             2         1              1         28805.09
# 4253       0.00             1         1              1         83056.22
# 4369  126362.57             2         1              1         97382.80
# 4556   98894.39             1         1              1          9596.40
# 5586  150355.35             2         1              1         35770.84
# 5675  104258.80             1         1              1           428.23
# 6885   94920.71             1         1              1         40339.90
# 7113  161884.99             1         1              1          9617.24
# 7806  123816.50             1         1              1         90162.35
# 7859   62717.84             2         1              1         13182.43
# 7985   96129.32             2         1              1          5983.70
# 9379       0.00             2         1              1         93255.85
# 9469  121172.97             1         1              1         56268.98
#
#      Exited KrediSkorDurumu SadıklıkDurumu ZenginlikDurumu  \
# 998       0          Yüksek    Sadık Değil       Varlıksız
# 1134      0          Yüksek    Sadık Değil       Varlıksız
# 1213      0          Yüksek    Sadık Değil       Varlıksız
# 1412      0          Yüksek    Sadık Değil       Varlıksız
# 1472      0          Yüksek    Sadık Değil       Varlıksız
# 2001      0          Yüksek    Sadık Değil       Varlıksız
# 2324      0          Yüksek    Sadık Değil       Varlıksız
# 2422      0          Yüksek    Sadık Değil       Varlıksız
# 3031      0          Yüksek    Sadık Değil       Varlıksız
# 3800      0          Yüksek    Sadık Değil       Varlıksız
# 4003      0          Yüksek    Sadık Değil       Varlıksız
# 4120      0          Yüksek    Sadık Değil       Varlıksız
# 4146      0          Yüksek    Sadık Değil       Varlıksız
# 4186      0          Yüksek    Sadık Değil       Varlıksız
# 4253      0          Yüksek    Sadık Değil       Varlıksız
# 4369      0          Yüksek    Sadık Değil       Varlıksız
# 4556      0          Yüksek    Sadık Değil       Varlıksız
# 5586      0          Yüksek    Sadık Değil       Varlıksız
# 5675      0          Yüksek    Sadık Değil       Varlıksız
# 6885      0          Yüksek    Sadık Değil       Varlıksız
# 7113      0          Yüksek    Sadık Değil       Varlıksız
# 7806      0          Yüksek    Sadık Değil       Varlıksız
# 7859      0          Yüksek    Sadık Değil       Varlıksız
# 7985      0          Yüksek    Sadık Değil       Varlıksız
# 9379      0          Yüksek    Sadık Değil       Varlıksız
# 9469      0          Yüksek    Sadık Değil       Varlıksız
#
#      VarlığıOrtalamaMaaştanDüşük
# 998                        Düşük
# 1134                       Düşük
# 1213                       Düşük
# 1412                       Düşük
# 1472                       Düşük
# 2001                       Düşük
# 2324                       Düşük
# 2422                       Düşük
# 3031                       Düşük
# 3800                       Düşük
# 4003                       Düşük
# 4120                       Düşük
# 4146                       Düşük
# 4186                       Düşük
# 4253                       Düşük
# 4369                       Düşük
# 4556                       Düşük
# 5586                       Düşük
# 5675                       Düşük
# 6885                       Düşük
# 7113                       Düşük
# 7806                       Düşük
# 7859                       Düşük
# 7985                       Düşük
# 9379                       Düşük
# 9469                       Düşük

# %%
# Burada ise X yaşından küçük erkeklere "Teknoloji Kredisi" adı altında bir teklif sunmak isteyelim bize bu kriterlere uygun müşterileri getirecek bir fonksiyon yazalım
def TeknolojiKredisi(X,df):
    teknolojiKredisi = data[
        (data["Age"] < X) & ( data["Gender"] == "Male")
    ]
    return teknolojiKredisi

# %%
krediTeklifiX2 = TeknolojiKredisi(30,data)

# %%
krediTeklifiX2
# Out:
#       CustomerId   Surname  CreditScore Geography Gender  Age Tenure  \
# 9       15592389        H?          684    France   Male   27      2
# 11      15737173   Andrews          497     Spain   Male   24      3
# 25      15738191   Maclean          577    France   Male   25      3
# 29      15656300  Lucciano          411    France   Male   29      0
# 57      15647091  Endrizzi          725   Germany   Male   19      0
# ...          ...       ...          ...       ...    ...  ...    ...
# 9957    15672237    Oluchi          633    France   Male   25      1
# 9972    15747927     Ch'in          758    France   Male   26      4
# 9973    15806455    Miller          611    France   Male   27      7
# 9989    15605622  McMillan          841     Spain   Male   28      4
# 9993    15569266    Rahman          644    France   Male   28      7
#
#         Balance NumOfProducts HasCrCard IsActiveMember  EstimatedSalary  \
# 9     134603.88             1         1              1         71725.73
# 11         0.00             2         1              0         76390.01
# 25         0.00             2         0              1        124508.29
# 29     59697.17             2         1              1         53483.21
# 57     75888.20             1         0              0         45613.75
# ...         ...           ...       ...            ...              ...
# 9957       0.00             1         1              0        100598.98
# 9972  155739.76             1         1              0        171552.02
# 9973       0.00             2         1              1        157474.10
# 9989       0.00             2         1              1        179436.60
# 9993  155060.41             1         1              0         29179.52
#
#      Exited KrediSkorDurumu SadıklıkDurumu ZenginlikDurumu  \
# 9         0          Yüksek    Sadık Değil       Varlıksız
# 11        0           Düşük    Sadık Değil       Varlıksız
# 25        0           Düşük    Sadık Değil        Varlıklı
# 29        0           Düşük    Sadık Değil       Varlıksız
# 57        0          Yüksek    Sadık Değil       Varlıksız
# ...     ...             ...            ...             ...
# 9957      0           Düşük    Sadık Değil        Varlıklı
# 9972      0          Yüksek    Sadık Değil        Varlıklı
# 9973      0           Düşük          Sadık        Varlıklı
# 9989      0          Yüksek    Sadık Değil        Varlıklı
# 9993      0           Düşük          Sadık       Varlıksız
#
#      VarlığıOrtalamaMaaştanDüşük
# 9                          Düşük
# 11                         Düşük
# 25                        Yüksek
# 29                         Düşük
# 57                         Düşük
# ...                          ...
# 9957                      Yüksek
# 9972                      Yüksek
# 9973                      Yüksek
# 9989                      Yüksek
# 9993                       Düşük
#
# [891 rows x 17 columns]

# %%
krediTeklifiX2[
    (krediTeklifiX2["IsActiveMember"] == 1) & (krediTeklifiX2["Exited"] == 0) & (krediTeklifiX2["HasCrCard"] == 1) & (krediTeklifiX2["KrediSkorDurumu"] == "Yüksek") & (krediTeklifiX2["SadıklıkDurumu"] == "Sadık Değil") & (krediTeklifiX2["ZenginlikDurumu"] == "Varlıksız")
]
# Out:
#       CustomerId    Surname  CreditScore Geography Gender  Age Tenure  \
# 9       15592389         H?          684    France   Male   27      2
# 479     15797736      Smith          658    France   Male   29      4
# 549     15600651     Ijendu          749    France   Male   24      1
# 1088    15645517     Philip          850     Spain   Male   22      2
# 1280    15671590         H?          741     Spain   Male   25      4
# 1327    15688007        Liu          703     Spain   Male   20      3
# 1989    15622454    Zaitsev          695     Spain   Male   28      0
# 2136    15621893   Bellucci          727    France   Male   18      4
# 2292    15779064  Chidiegwu          677    France   Male   27      2
# 2328    15664204      Meany          706     Spain   Male   29      2
# 3037    15741094     Sagese          693    France   Male   21      1
# 3330    15657439       Chao          738    France   Male   18      4
# 3512    15657779     Boylan          806     Spain   Male   18      3
# 3669    15576185   Sinclair          653    France   Male   29      2
# 3670    15660809     Loving          850    France   Male   28      4
# 3999    15665062   Lucchese          696    France   Male   19      1
# 4109    15807768       Cohn          702   Germany   Male   28      1
# 5211    15662263   Castillo          749   Germany   Male   22      4
# 5616    15585256   Iloerika          805     Spain   Male   26      2
# 5843    15813327     Romani          710    France   Male   21      4
# 7285    15725028   Chialuka          679    France   Male   29      3
# 7647    15674583  Trevisani          768    France   Male   25      0
# 8091    15715510   Eluemuno          768    France   Male   29      2
# 8429    15681671   Nkemjika          850   Germany   Male   28      2
# 8439    15692931      Hsing          670    France   Male   22      2
# 8508    15616833       Wang          678     Spain   Male   27      2
# 8721    15689671    Packham          775     Spain   Male   27      4
# 8785    15801293         Ni          850   Germany   Male   27      1
# 9150    15602030    Ramirez          717    France   Male   28      4
# 9246    15682523   Chigozie          762    France   Male   20      1
# 9339    15722845    Meldrum          665     Spain   Male   29      1
# 9419    15798605       Tien          686   Germany   Male   26      1
# 9457    15797822   Kingsley          678    France   Male   28      2
# 9855    15797502       Lord          706     Spain   Male   24      2
# 9943    15659495         Fu          784     Spain   Male   23      2
# 9955    15611338  Kashiwagi          714     Spain   Male   29      4
#
#         Balance NumOfProducts HasCrCard IsActiveMember  EstimatedSalary  \
# 9     134603.88             1         1              1         71725.73
# 479    80262.60             1         1              1         20612.82
# 549        0.00             3         1              1         47911.03
# 1088       0.00             2         1              1          9684.52
# 1280       0.00             2         1              1         73873.65
# 1327  165260.98             1         1              1         41626.78
# 1989   96020.86             1         1              1         57992.49
# 2136  133550.67             1         1              1         46941.41
# 2292       0.00             2         1              1         20092.89
# 2328       0.00             2         1              1         18255.51
# 3037       0.00             2         1              1          3494.02
# 3330       0.00             2         1              1         47799.15
# 3512       0.00             2         1              1         86994.54
# 3669       0.00             2         1              1         41671.81
# 3670       0.00             2         1              1         12409.01
# 3999  110928.51             1         1              1          2766.63
# 4109  103033.83             1         1              1         40321.87
# 5211   94762.16             2         1              1         42241.54
# 5616       0.00             2         1              1         25042.10
# 5843  109130.96             2         1              1         56191.99
# 7285       0.00             2         1              1         63687.06
# 7647   78396.08             1         1              1          8316.19
# 8091   95984.69             2         1              1         73686.75
# 8429  101100.22             2         1              1         35337.31
# 8439  114991.45             1         1              1         37392.56
# 8508       0.00             2         1              1         13221.25
# 8721       0.00             1         1              1         40807.26
# 8785  101278.25             2         1              1         26265.18
# 9150  128206.79             1         1              1         54272.12
# 9246  139432.55             1         1              1         85606.83
# 9339  182781.74             2         1              1         63732.90
# 9419   57422.62             1         1              1         79189.40
# 9457  109137.12             1         1              1         58814.41
# 9855  141078.57             1         1              1         24402.87
# 9943       0.00             1         1              1          6847.73
# 9955       0.00             2         1              1         37605.90
#
#      Exited KrediSkorDurumu SadıklıkDurumu ZenginlikDurumu  \
# 9         0          Yüksek    Sadık Değil       Varlıksız
# 479       0          Yüksek    Sadık Değil       Varlıksız
# 549       0          Yüksek    Sadık Değil       Varlıksız
# 1088      0          Yüksek    Sadık Değil       Varlıksız
# 1280      0          Yüksek    Sadık Değil       Varlıksız
# 1327      0          Yüksek    Sadık Değil       Varlıksız
# 1989      0          Yüksek    Sadık Değil       Varlıksız
# 2136      0          Yüksek    Sadık Değil       Varlıksız
# 2292      0          Yüksek    Sadık Değil       Varlıksız
# 2328      0          Yüksek    Sadık Değil       Varlıksız
# 3037      0          Yüksek    Sadık Değil       Varlıksız
# 3330      0          Yüksek    Sadık Değil       Varlıksız
# 3512      0          Yüksek    Sadık Değil       Varlıksız
# 3669      0          Yüksek    Sadık Değil       Varlıksız
# 3670      0          Yüksek    Sadık Değil       Varlıksız
# 3999      0          Yüksek    Sadık Değil       Varlıksız
# 4109      0          Yüksek    Sadık Değil       Varlıksız
# 5211      0          Yüksek    Sadık Değil       Varlıksız
# 5616      0          Yüksek    Sadık Değil       Varlıksız
# 5843      0          Yüksek    Sadık Değil       Varlıksız
# 7285      0          Yüksek    Sadık Değil       Varlıksız
# 7647      0          Yüksek    Sadık Değil       Varlıksız
# 8091      0          Yüksek    Sadık Değil       Varlıksız
# 8429      0          Yüksek    Sadık Değil       Varlıksız
# 8439      0          Yüksek    Sadık Değil       Varlıksız
# 8508      0          Yüksek    Sadık Değil       Varlıksız
# 8721      0          Yüksek    Sadık Değil       Varlıksız
# 8785      0          Yüksek    Sadık Değil       Varlıksız
# 9150      0          Yüksek    Sadık Değil       Varlıksız
# 9246      0          Yüksek    Sadık Değil       Varlıksız
# 9339      0          Yüksek    Sadık Değil       Varlıksız
# 9419      0          Yüksek    Sadık Değil       Varlıksız
# 9457      0          Yüksek    Sadık Değil       Varlıksız
# 9855      0          Yüksek    Sadık Değil       Varlıksız
# 9943      0          Yüksek    Sadık Değil       Varlıksız
# 9955      0          Yüksek    Sadık Değil       Varlıksız
#
#      VarlığıOrtalamaMaaştanDüşük
# 9                          Düşük
# 479                        Düşük
# 549                        Düşük
# 1088                       Düşük
# 1280                       Düşük
# 1327                       Düşük
# 1989                       Düşük
# 2136                       Düşük
# 2292                       Düşük
# 2328                       Düşük
# 3037                       Düşük
# 3330                       Düşük
# 3512                       Düşük
# 3669                       Düşük
# 3670                       Düşük
# 3999                       Düşük
# 4109                       Düşük
# 5211                       Düşük
# 5616                       Düşük
# 5843                       Düşük
# 7285                       Düşük
# 7647                       Düşük
# 8091                       Düşük
# 8429                       Düşük
# 8439                       Düşük
# 8508                       Düşük
# 8721                       Düşük
# 8785                       Düşük
# 9150                       Düşük
# 9246                       Düşük
# 9339                       Düşük
# 9419                       Düşük
# 9457                       Düşük
# 9855                       Düşük
# 9943                       Düşük
# 9955                       Düşük

# %%
# Burada da bakiyesi Tahmini maaş'dan küçük olanlara "İhtiyaç kredisi" adı altında kredi teklifi sunalım
def İhtiyacKredisi(df):
    ihtiyaçKredisi = data[
        (data["Balance"] < data["EstimatedSalary"])
    ]
    return ihtiyaçKredisi

# %%
krediTeklifiX3 = İhtiyacKredisi(data)

# %%
krediTeklifiX3[
    (krediTeklifiX3["IsActiveMember"] == 1) & (krediTeklifiX3["Exited"] == 0) & (krediTeklifiX3["HasCrCard"] == 1) & (krediTeklifiX3["KrediSkorDurumu"] == "Yüksek") & (krediTeklifiX3["SadıklıkDurumu"] == "Sadık Değil") & (krediTeklifiX3["ZenginlikDurumu"] == "Varlıksız")
]
# Out:
#       CustomerId            Surname  CreditScore Geography Gender  Age Tenure  \
# 411     15760431               Pino          850    France   Male   38      1
# 456     15747960           Eluemuno          733    France   Male   33      3
# 529     15694272         Nkemakolam          673    France   Male   30      1
# 549     15600651             Ijendu          749    France   Male   24      1
# 558     15717046  Wentworth-Shields          741     Spain   Male   53      3
# ...          ...                ...          ...       ...    ...  ...    ...
# 9745    15603883              Ch'in          818    France   Male   36      4
# 9857    15779423                 K?          716    France   Male   39      1
# 9867    15620936             Warren          787    France   Male   32      4
# 9943    15659495                 Fu          784     Spain   Male   23      2
# 9955    15611338          Kashiwagi          714     Spain   Male   29      4
#
#        Balance NumOfProducts HasCrCard IsActiveMember  EstimatedSalary Exited  \
# 411       0.00             2         1              1         80006.65      0
# 456       0.00             1         1              1          7666.73      0
# 529   64097.75             1         1              1         77783.35      0
# 549       0.00             3         1              1         47911.03      0
# 558       0.00             2         1              1         38913.68      0
# ...        ...           ...       ...            ...              ...    ...
# 9745      0.00             2         1              1          8037.03      0
# 9857  70657.61             2         1              1         76476.05      0
# 9867      0.00             2         1              1         13238.93      0
# 9943      0.00             1         1              1          6847.73      0
# 9955      0.00             2         1              1         37605.90      0
#
#      KrediSkorDurumu SadıklıkDurumu ZenginlikDurumu  \
# 411           Yüksek    Sadık Değil       Varlıksız
# 456           Yüksek    Sadık Değil       Varlıksız
# 529           Yüksek    Sadık Değil       Varlıksız
# 549           Yüksek    Sadık Değil       Varlıksız
# 558           Yüksek    Sadık Değil       Varlıksız
# ...              ...            ...             ...
# 9745          Yüksek    Sadık Değil       Varlıksız
# 9857          Yüksek    Sadık Değil       Varlıksız
# 9867          Yüksek    Sadık Değil       Varlıksız
# 9943          Yüksek    Sadık Değil       Varlıksız
# 9955          Yüksek    Sadık Değil       Varlıksız
#
#      VarlığıOrtalamaMaaştanDüşük
# 411                        Düşük
# 456                        Düşük
# 529                        Düşük
# 549                        Düşük
# 558                        Düşük
# ...                          ...
# 9745                       Düşük
# 9857                       Düşük
# 9867                       Düşük
# 9943                       Düşük
# 9955                       Düşük
#
# [153 rows x 17 columns]

# %%
# Burada da Hesabı olan ama kredi kartı olmayan, kredi skoru yüksek ve varlığı ortalama maaştan düşük olanlara "Kredi Kartı" adı altında kredi teklifi sunalım
def KrediKartı(df):
    krediKartı = data[
        (data["HasCrCard"] == 0) & (data["KrediSkorDurumu"] == "Yüksek") & (data["VarlığıOrtalamaMaaştanDüşük"] == "Düşük")
    ]
    return krediKartı

# %%
krediTeklifiX4 = KrediKartı(data)

# %%
krediTeklifiX4
# Out:
#       CustomerId   Surname  CreditScore Geography  Gender  Age Tenure  \
# 3       15701354      Boni          699    France  Female   39      1
# 23      15725737    Mosman          669    France    Male   46      3
# 37      15729599   Lorenzo          804     Spain    Male   33      7
# 57      15647091  Endrizzi          725   Germany    Male   19      0
# 60      15651280    Hunter          742   Germany    Male   35      5
# ...          ...       ...          ...       ...     ...  ...    ...
# 9962    15594612     Flynn          702     Spain    Male   44      9
# 9979    15692664    Diribe          677    France  Female   58      1
# 9980    15719276      T'ao          741     Spain    Male   35      6
# 9986    15581736  Bartlett          673   Germany    Male   47      1
# 9997    15584532       Liu          709    France  Female   36      7
#
#         Balance NumOfProducts HasCrCard IsActiveMember  EstimatedSalary  \
# 3          0.00             2         0              0         93826.63
# 23         0.00             2         0              1          8487.75
# 37     76548.60             1         0              1         98453.45
# 57     75888.20             1         0              0         45613.75
# 60    136857.00             1         0              0         84509.57
# ...         ...           ...       ...            ...              ...
# 9962       0.00             1         0              0         59207.41
# 9979   90022.85             1         0              1          2988.28
# 9980   74371.49             1         0              0         99595.67
# 9986  183579.54             2         0              1         34047.54
# 9997       0.00             1         0              1         42085.58
#
#      Exited KrediSkorDurumu SadıklıkDurumu ZenginlikDurumu  \
# 3         0          Yüksek    Sadık Değil       Varlıksız
# 23        0          Yüksek    Sadık Değil       Varlıksız
# 37        0          Yüksek          Sadık       Varlıksız
# 57        0          Yüksek    Sadık Değil       Varlıksız
# 60        0          Yüksek          Sadık       Varlıksız
# ...     ...             ...            ...             ...
# 9962      1          Yüksek          Sadık       Varlıksız
# 9979      0          Yüksek    Sadık Değil       Varlıksız
# 9980      0          Yüksek          Sadık       Varlıksız
# 9986      0          Yüksek    Sadık Değil       Varlıksız
# 9997      1          Yüksek          Sadık       Varlıksız
#
#      VarlığıOrtalamaMaaştanDüşük
# 3                          Düşük
# 23                         Düşük
# 37                         Düşük
# 57                         Düşük
# 60                         Düşük
# ...                          ...
# 9962                       Düşük
# 9979                       Düşük
# 9980                       Düşük
# 9986                       Düşük
# 9997                       Düşük
#
# [745 rows x 17 columns]

# %%
# burada da ise uzun süreli müşterimiz olup kredi kartı kullanmayanlara özel "Sürekli Kredi Kartı" adı altında kredi teklifi sunalım
def surekliKrediKartı(df):
    surekliKrediKartı = data[
        (data["SadıklıkDurumu"] == "Sadık") & (data["HasCrCard"] == 0)
    ]
    return surekliKrediKartı

# %%
krediTeklifiX5 = surekliKrediKartı(data)

# %%
krediTeklifiX5
# Out:
#       CustomerId        Surname  CreditScore Geography  Gender  Age Tenure  \
# 10      15767821         Bearce          528    France    Male   31      6
# 13      15691483           Chin          549    France  Female   25      5
# 18      15661507        Muldrow          587     Spain    Male   45      6
# 27      15700772        Nebechi          571    France    Male   44      9
# 31      15706552  Odinakachukwu          533    France    Male   36      7
# ...          ...            ...          ...       ...     ...  ...    ...
# 9964    15642785        Douglas          479    France    Male   34      5
# 9968    15733491       McGregor          512   Germany  Female   40      8
# 9969    15806360            Hou          609    France    Male   41      6
# 9980    15719276           T'ao          741     Spain    Male   35      6
# 9997    15584532            Liu          709    France  Female   36      7
#
#         Balance NumOfProducts HasCrCard IsActiveMember  EstimatedSalary  \
# 10    102016.72             2         0              0         80181.12
# 13         0.00             2         0              0        190857.79
# 18         0.00             1         0              0        158684.81
# 27         0.00             2         0              0         38433.35
# 31     85311.70             1         0              1        156731.91
# ...         ...           ...       ...            ...              ...
# 9964  117593.48             2         0              0        113308.29
# 9968  153537.57             2         0              0         23101.13
# 9969       0.00             1         0              1        112585.19
# 9980   74371.49             1         0              0         99595.67
# 9997       0.00             1         0              1         42085.58
#
#      Exited KrediSkorDurumu SadıklıkDurumu ZenginlikDurumu  \
# 10        0           Düşük          Sadık       Varlıksız
# 13        0           Düşük          Sadık        Varlıklı
# 18        0           Düşük          Sadık        Varlıklı
# 27        0           Düşük          Sadık       Varlıksız
# 31        0           Düşük          Sadık        Varlıklı
# ...     ...             ...            ...             ...
# 9964      0           Düşük          Sadık        Varlıklı
# 9968      0           Düşük          Sadık       Varlıksız
# 9969      0           Düşük          Sadık        Varlıklı
# 9980      0          Yüksek          Sadık       Varlıksız
# 9997      1          Yüksek          Sadık       Varlıksız
#
#      VarlığıOrtalamaMaaştanDüşük
# 10                         Düşük
# 13                        Yüksek
# 18                        Yüksek
# 27                         Düşük
# 31                        Yüksek
# ...                          ...
# 9964                      Yüksek
# 9968                       Düşük
# 9969                      Yüksek
# 9980                       Düşük
# 9997                       Düşük
#
# [1597 rows x 17 columns]
